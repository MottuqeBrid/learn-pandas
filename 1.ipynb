# %% [markdown]
# # Pandas

# %%
# Import pandas
import pandas as pd

# %%
city=['Delhi','Mumbai','Chennai','Kolkata']
city
# Out:
# ['Delhi', 'Mumbai', 'Chennai', 'Kolkata']

# %%
df=pd.DataFrame(city)
df
# Out:
#          0
# 0    Delhi
# 1   Mumbai
# 2  Chennai
# 3  Kolkata

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4 non-null      object
# dtypes: object(1)
# memory usage: 164.0+ bytes

# %%
row,col=df.shape
row,col
# Out:
# (4, 1)

# %%
df1=pd.DataFrame(city,columns=['City in India'], index=['city-1','city-2','city-3','city-4'])
df1
# Out:
#        City in India
# city-1         Delhi
# city-2        Mumbai
# city-3       Chennai
# city-4       Kolkata

# %%
city2=['New York','Los Angeles','Chicago','Houston']
city2
df2=pd.DataFrame(zip(city,city2),columns=["City in India","City in USA"], index=['city-1','city-2','city-3','city-4'])
df2
# Out:
#        City in India  City in USA
# city-1         Delhi     New York
# city-2        Mumbai  Los Angeles
# city-3       Chennai      Chicago
# city-4       Kolkata      Houston

# %%
city3=[["Dhaka","Bangladesh"],["Kathmandu","Nepal"],["Thimphu","Bhutan"],["Vientiane","Laos"]]
city3
df3=pd.DataFrame(city3,columns=["City","Country"], index=['city-1','city-2','city-3','city-4'])
df3
# Out:
#              City     Country
# city-1      Dhaka  Bangladesh
# city-2  Kathmandu       Nepal
# city-3    Thimphu      Bhutan
# city-4  Vientiane        Laos

# %%
dict1={
    "city-1":city,
    "city-2":city2,
}
df4=pd.DataFrame(dict1)
df4
# Out:
#     city-1       city-2
# 0    Delhi     New York
# 1   Mumbai  Los Angeles
# 2  Chennai      Chicago
# 3  Kolkata      Houston

# %%
# Importing csv file
df_csv=pd.read_csv("Screen Time Data.csv")
df_csv.head(10)
# df_csv.info()
# df_csv.values
df_csv.columns
df_csv.index
# df_csv.Date
df_csv[["Social Networking"]]
# Out:
#     Social Networking
# 0                  89
# 1                  78
# 2                  52
# 3                  69
# 4                  35
# 5                  68
# 6                  56
# 7                  98
# 8                  25
# 9                  76
# 10                 75
# 11                 42
# 12                 46
# 13                 40
# 14                 90
# 15                 60
# 16                 64
# 17                 34
# 18                109
# 19                 81
# 20                 70
# 21                 53
# 22                 42
# 23                 93
# 24                 49
# 25                 28
# 26                 37
# 27                 41

# %%
df_csv[["Social Networking","Productivity"]].head(5)
df_csv["Social Networking"].sort_values(ascending=False)
# Out:
# 18    109
# 7      98
# 23     93
# 14     90
# 0      89
# 19     81
# 1      78
# 9      76
# 10     75
# 20     70
# 3      69
# 5      68
# 16     64
# 15     60
# 6      56
# 21     53
# 2      52
# 24     49
# 12     46
# 11     42
# 22     42
# 27     41
# 13     40
# 26     37
# 4      35
# 17     34
# 25     28
# 8      25
# Name: Social Networking, dtype: int64

# %%
df_csv.describe()
# Out:
#            index  Total Screen Time   Social Networking  \
# count  28.000000           28.000000          28.000000
# mean   13.500000          113.250000          60.714286
# std     8.225975           43.562322          22.853571
# min     0.000000           52.000000          25.000000
# 25%     6.750000           83.500000          41.750000
# 50%    13.500000          111.000000          58.000000
# 75%    20.250000          137.250000          76.500000
# max    27.000000          198.000000         109.000000
#
#        Reading and Reference      Other  Productivity  Health and Fitness  \
# count              28.000000  28.000000     28.000000           28.000000
# mean                8.714286  14.821429      9.071429            1.285714
# std                 9.340700  13.754605      6.097532            3.952094
# min                 0.000000   0.000000      2.000000            0.000000
# 25%                 2.000000   4.750000      3.000000            0.000000
# ...

# %%
df_csv.select_dtypes(include=["number"]).corr()
# Out:
#                           index  Total Screen Time   Social Networking  \
# index                  1.000000           -0.344952          -0.218093
# Total Screen Time     -0.344952            1.000000           0.710864
# Social Networking     -0.218093            0.710864           1.000000
# Reading and Reference -0.360073            0.185685           0.004461
# Other                 -0.537331            0.333433           0.234066
# Productivity           0.012553            0.344195           0.124539
# Health and Fitness    -0.178863            0.201360          -0.092968
# Entertainment         -0.113858            0.343897           0.132916
# Creativity             0.221908           -0.409306          -0.214764
# Yoga                   0.857690           -0.258123          -0.110716
#
#                        Reading and Reference     Other  Productivity  \
# index                              -0.360073 -0.537331      0.012553
# ...

# %%
import seaborn as sns
sns.heatmap(df_csv.select_dtypes(include=["number"]).corr(),annot=True)
# Out:
# <Axes: >

# %%
df_csv[df_csv["Social Networking"]>50]
# Out:
#     index      Date   Week Day  Total Screen Time   Social Networking  \
# 0       0  04/17/19  Wednesday                 187                 89
# 1       1  04/18/19   Thursday                 123                 78
# 2       2  04/19/19     Friday                 112                 52
# 3       3  04/20/19   Saturday                 101                 69
# 5       5  04/22/19     Monday                 189                 68
# 6       6  04/23/19    Tuesday                 158                 56
# 7       7  04/24/19  Wednesday                 135                 98
# 9       9  04/26/19     Friday                 198                 76
# 10     10  04/27/19   Saturday                 116                 75
# 14     14  05/01/19  Wednesday                 127                 90
# 15     15  05/02/19   Thursday                 170                 60
# 16     16  05/03/19     Friday                  91                 64
# ...

# %%
df_csv[(df_csv["Week Day"]=="Sunday") | (df_csv["Week Day"]=="Saturday")]
# Out:
#     index      Date  Week Day  Total Screen Time   Social Networking  \
# 3       3  04/20/19  Saturday                 101                 69
# 4       4  04/21/19    Sunday                  56                 35
# 10     10  04/27/19  Saturday                 116                 75
# 11     11  04/28/19    Sunday                  85                 42
# 17     17  05/04/19  Saturday                  58                 34
# 18     18  05/05/19    Sunday                 133                109
# 24     24  05/11/19  Saturday                  58                 49
# 25     25  05/12/19    Sunday                  52                 28
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 3                       9     38             2                   0
# 4                       2     43             3                   0
# 10                     10     20             5                   0
# 11                     22      4             2                   0
# ...

# %%
df_csv[df_csv["Week Day"].isin(["Sunday","Saturday"])]
# Out:
#     index      Date  Week Day  Total Screen Time   Social Networking  \
# 3       3  04/20/19  Saturday                 101                 69
# 4       4  04/21/19    Sunday                  56                 35
# 10     10  04/27/19  Saturday                 116                 75
# 11     11  04/28/19    Sunday                  85                 42
# 17     17  05/04/19  Saturday                  58                 34
# 18     18  05/05/19    Sunday                 133                109
# 24     24  05/11/19  Saturday                  58                 49
# 25     25  05/12/19    Sunday                  52                 28
#
#     Reading and Reference  Other  Productivity  Health and Fitness  \
# 3                       9     38             2                   0
# 4                       2     43             3                   0
# 10                     10     20             5                   0
# 11                     22      4             2                   0
# ...
