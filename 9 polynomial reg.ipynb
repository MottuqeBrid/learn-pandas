# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
df2=pd.read_csv('nonlinear_data.csv')
df2.head()
# Out:
#          x         y
# 0  0.00000 -0.155043
# 1  0.02004  0.081809
# 2  0.04008 -0.014298
# 3  0.06012  0.143978
# 4  0.08016  0.019553

# %%
x_nonlinear = df2[['x']]
y_nonlinear = df2[['y']]

# %%
poly=PolynomialFeatures(degree=6) # polynomial regression with degree 2
x_poly=poly.fit_transform(x_nonlinear)

# %%
x_poly.shape
# Out:
# (500, 7)

# %%
reg_poly=LinearRegression()
reg_poly.fit(x_poly,y_nonlinear)
# Out:
# LinearRegression()

# %%
reg_poly.score(x_poly,y_nonlinear)
# Out:
# 0.9930624844497353

# %%
plt.scatter(x_nonlinear,y_nonlinear, color="green", label="Data with Non-linear Relationship")
plt.plot(x_nonlinear, 2*np.sin(x_nonlinear), color="orange", label="True Non-linear Relationship")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Non-linear Relationship")
plt.legend()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_poly, y_nonlinear, test_size=0.3, random_state=1)

# %%
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_train,y_train)
# Out:
# 0.9939293669434804

# %%
reg.score(x_test,y_test)
# Out:
# 0.9905664282629504
