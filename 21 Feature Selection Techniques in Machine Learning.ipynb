# %% [markdown]
# # Feature Selection Techniques in Machine Learning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cardio_train.csv", sep=";")
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df.shape
# Out:
# (70000, 13)

# %%
df["cardio"].value_counts()
# Out:
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64

# %%
sns.countplot(x='cardio', data=df)
plt.show()

# %%
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# np.False_

# %%
sns.countplot(
    x="gender",
    hue="cardio",
    data=df,
    palette="colorblind",
    edgecolor=sns.color_palette("dark", n_colors=1)[0],
)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
# sns.countplot(x="age", hue="cardio", data=df, palette="colorblind")

# %%
df["year"] = (df["age"] / 365).round(0).astype(int)

# %%
df["year"]
# Out:
# 0        50
# 1        55
# 2        52
# 3        48
# 4        48
#          ..
# 69995    53
# 69996    62
# 69997    52
# 69998    61
# 69999    56
# Name: year, Length: 70000, dtype: int64

# %%
sns.countplot(x="year", hue="cardio", data=df, palette="colorblind")
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
df.corr()
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000  0.003457  0.003502 -0.003038 -0.001830  0.003356
# age          0.003457  1.000000 -0.022811 -0.081515  0.053684  0.020764
# gender       0.003502 -0.022811  1.000000  0.499033  0.155406  0.006005
# height      -0.003038 -0.081515  0.499033  1.000000  0.290968  0.005488
# weight      -0.001830  0.053684  0.155406  0.290968  1.000000  0.030702
# ap_hi        0.003356  0.020764  0.006005  0.005488  0.030702  1.000000
# ap_lo       -0.002529  0.017647  0.015254  0.006150  0.043710  0.016086
# cholesterol  0.006106  0.154424 -0.035821 -0.050226  0.141768  0.023778
# gluc         0.002467  0.098703 -0.020491 -0.018595  0.106857  0.011841
# smoke       -0.003699 -0.047633  0.338135  0.187989  0.067780 -0.000922
# alco         0.001210 -0.029723  0.170966  0.094419  0.067113  0.001408
# active       0.003755 -0.009927  0.005866 -0.006570 -0.016867 -0.000033
# ...

# %%
df = df.drop(["year"], axis=1)

# %%
x = df.drop("cardio", axis=1)
y = df["cardio"]

# %%
x
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active
# ...

# %%
from sklearn.feature_selection import SelectKBest

# %%
from sklearn.feature_selection import f_classif

# %%
fit_feature = SelectKBest(score_func=f_classif)

# %%
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
fit_feature.fit(x, y)
# Out:
# SelectKBest()

# %%
scores_col = pd.DataFrame(fit_feature.scores_, columns=["scores"])
scores_col
# Out:
#          scores
# 0      1.010461
# 1   4209.007957
# 2      4.603641
# 3      8.197397
# 4   2388.777887
# 5    208.339524
# 6    303.629011
# 7   3599.361137
# 8    562.772977
# 9     16.790541
# 10     3.761355
# 11    89.091494

# %%
name_col = pd.DataFrame(x.columns)
top_features = pd.concat([name_col, scores_col], axis=1)
top_features.columns = ["Feature Name", "Score"]
top_features
# Out:
#    Feature Name        Score
# 0            id     1.010461
# 1           age  4209.007957
# 2        gender     4.603641
# 3        height     8.197397
# 4        weight  2388.777887
# 5         ap_hi   208.339524
# 6         ap_lo   303.629011
# 7   cholesterol  3599.361137
# 8          gluc   562.772977
# 9         smoke    16.790541
# 10         alco     3.761355
# 11       active    89.091494

# %%
top_features.nlargest(8, "Score")
# Out:
#    Feature Name        Score
# 1           age  4209.007957
# 7   cholesterol  3599.361137
# 4        weight  2388.777887
# 8          gluc   562.772977
# 6         ap_lo   303.629011
# 5         ap_hi   208.339524
# 11       active    89.091494
# 9         smoke    16.790541

# %%
x = x[top_features.nlargest(8, "Score")["Feature Name"].tolist()]

# %%
x
# Out:
#          age  cholesterol  weight  gluc  ap_lo  ap_hi  active  smoke
# 0      18393            1    62.0     1     80    110       1      0
# 1      20228            3    85.0     1     90    140       1      0
# 2      18857            3    64.0     1     70    130       0      0
# 3      17623            1    82.0     1    100    150       1      0
# 4      17474            1    56.0     1     60    100       0      0
# ...      ...          ...     ...   ...    ...    ...     ...    ...
# 69995  19240            1    76.0     1     80    120       1      1
# 69996  22601            2   126.0     2     90    140       1      0
# 69997  19066            3   105.0     1     90    180       0      0
# 69998  22431            1    72.0     2     80    135       0      0
# 69999  20540            2    72.0     1     80    120       1      0
#
# [70000 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.3, random_state=1
)

# %%
x_train
# Out:
#          age  cholesterol  weight  gluc  ap_lo  ap_hi  active  smoke
# 23561  16136            1    71.0     1     80    100       1      1
# 34858  14615            2    69.0     1     80    140       1      0
# 54953  20507            1    65.0     1     80    120       1      0
# 59230  16720            1    53.0     1     60    100       1      0
# 1730   21050            1    71.0     1     90    140       1      0
# ...      ...          ...     ...   ...    ...    ...     ...    ...
# 49100  21289            1    78.0     1     80    120       1      0
# 20609  19116            1    68.0     1     80    120       0      0
# 21440  18049            1    82.0     1     80    120       1      0
# 50057  21957            1    77.0     1     80    120       0      0
# 5192   20671            2    65.0     2     90    160       1      0
#
# [49000 rows x 8 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
# rfc.fit(x_train, y_train)

# %%
# rfc.score(x_test, y_test)
# Past 0.7162380952380952

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()

# %%
# dtc.fit(x_train, y_train)

# %%
# dtc.score(x_test, y_test)
# Past 0.635

# %%
from sklearn.svm import SVC
svc = SVC()

# %%
# svc.fit(x_train, y_train)

# %%
# svc.score(x_test, y_test)
# Past 0.6880952380952381

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
model_etc = ExtraTreesClassifier()

# %%
model_etc.fit(x, y)
# Out:
# ExtraTreesClassifier()

# %%
model_etc.feature_importances_
# Out:
# array([0.4490895 , 0.04520118, 0.19665885, 0.00844421, 0.10658023,
#        0.18853804, 0.00324149, 0.0022465 ])

# %%
top = pd.Series(model_etc.feature_importances_, index=x.columns)

# %%
top
# Out:
# age            0.449090
# cholesterol    0.045201
# weight         0.196659
# gluc           0.008444
# ap_lo          0.106580
# ap_hi          0.188538
# active         0.003241
# smoke          0.002247
# dtype: float64

# %%
top.nlargest(8).plot(kind="pie", autopct='%1.1f%%')
# Out:
# <Axes: >
